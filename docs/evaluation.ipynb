# %% [markdown]
# # Evaluation
#
# This file contains logic for:
# - main function for train and save model
# - evaluation: first use nake-eye:visualize / second use different methods
# - set checkpoints/ train the model(2-10 epoch)
# - possible upgrades:
# 1. ema for sampling and train ema in training
# 2. patience
# 3. scheduler
# 4. dropout
# 5. freeze and fine tune
#
# - test dataset
# - manually demaged data
# - metrics principles and parameter
#
#
# some trials (delete them afterwards) are also contained

# %%
! git add .
